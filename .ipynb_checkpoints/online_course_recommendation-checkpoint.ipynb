# %%
import sys

print(sys.executable)
# Out:
# D:\anaconda\envs\excelr\python.exe

# %%
# !pip install scikit-surprise --upgrade
# !pip install numpy==1.26.4
# Out:
# Requirement already satisfied: scikit-surprise in D:\anaconda\envs\excelr\Lib\site-packages (1.1.5)
# Requirement already satisfied: joblib>=1.4.0 in D:\anaconda\envs\excelr\Lib\site-packages (from scikit-surprise) (1.5.3)
# Requirement already satisfied: numpy>=1.24.1 in D:\anaconda\envs\excelr\Lib\site-packages (from scikit-surprise) (1.26.4)
# Requirement already satisfied: scipy>=1.10.0 in D:\anaconda\envs\excelr\Lib\site-packages (from scikit-surprise) (1.17.1)
# Requirement already satisfied: numpy==1.26.4 in D:\anaconda\envs\excelr\Lib\site-packages (1.26.4)

# %%
import matplotlib

print(matplotlib.__version__)
print(matplotlib.__file__)
# Out:
# 3.11.0
# D:\anaconda\envs\excelr\Lib\site-packages\matplotlib\__init__.py

# %%
# Import required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics.pairwise import cosine_similarity
from scipy.sparse import csr_matrix
from surprise import Dataset, Reader, KNNBasic
from surprise.model_selection import cross_validate
import time
import warnings
print("All imports successful!")
# Set random seed for reproducibility
np.random.seed(42)

# Configure display options
pd.set_option('display.max_columns', None)
warnings.filterwarnings('ignore')
# Out:
# All imports successful!

# %%
def load_data(file_path):
    """Load the dataset with optimized data types"""
    print("Loading data...")
    start_time = time.time()

    dtype = {
        'user_id': 'int32',
        'course_id': 'int32',
        'course_duration_hours': 'float32',
        'course_price': 'float32',
        'feedback_score': 'float32',
        'time_spent_hours': 'float32',
        'previous_courses_taken': 'int8',
        'rating': 'float32',
        'enrollment_numbers': 'int32'
    }

    df = pd.read_csv(file_path, dtype=dtype)

    print(f"Data loaded in {time.time() - start_time:.2f} seconds")
    print(f"Dataset shape: {df.shape}")

    return df

# %%
import os

print(os.getcwd())
# Out:
# C:\Users\risha\excelr\project 1\project OCR

# %%
file_path = "online_course_recommendation_v2.csv"

df = load_data(file_path)
df.head()
# Out:
# Loading data...
# Data loaded in 0.20 seconds
# Dataset shape: (100000, 14)
#    user_id  course_id                       course_name       instructor  \
# 0    15796       9366              Python for Beginners      Emma Harris
# 1      861       1928   Cybersecurity for Professionals  Alexander Young
# 2    38159       9541  DevOps and Continuous Deployment   Dr. Mia Walker
# 3    44733       3708   Project Management Fundamentals   Benjamin Lewis
# 4    11285       3361       Ethical Hacking Masterclass     Daniel White
#
#    course_duration_hours certification_offered difficulty_level  rating  \
# 0              39.099998                   Yes         Beginner     5.0
# 1              36.299999                   Yes         Beginner     4.3
# 2              13.400000                   Yes         Beginner     3.9
# 3              58.299999                   Yes         Beginner     3.1
# 4              30.799999                   Yes         Beginner     2.8
#
#    enrollment_numbers  course_price  feedback_score study_material_available  \
# 0               21600    317.500000           0.797                      Yes
# 1               15379     40.990002           0.770                      Yes
# 2                6431    380.809998           0.772                      Yes
# 3               48245    342.799988           0.969                       No
# 4               34556    381.010010           0.555                      Yes
#
#    time_spent_hours  previous_courses_taken
# 0         17.600000                       4
# 1         28.969999                       9
# 2         52.439999                       4
# 3         22.290001                       6
# 4         22.010000                       5

# %%
def clean_data(df):
    """Clean and preprocess the data"""
    print("\nCleaning and preprocessing data...")

    # Convert boolean columns
    df['certification_offered'] = df['certification_offered'].map({'Yes': 1, 'No': 0})
    df['study_material_available'] = df['study_material_available'].map({'Yes': 1, 'No': 0})

    # Convert difficulty_level to ordinal
    difficulty_map = {'Beginner': 0, 'Intermediate': 1, 'Advanced': 2}
    df['difficulty_level'] = df['difficulty_level'].map(difficulty_map)

    # Drop duplicates if any
    initial_size = len(df)
    df = df.drop_duplicates()
    final_size = len(df)

    print(f"Removed {initial_size - final_size} duplicate rows")
    print("\nData types after cleaning:")
    print(df.dtypes)

    return df

df = clean_data(df)
# Out:
# Cleaning and preprocessing data...
# Removed 0 duplicate rows
#
# Data types after cleaning:
# user_id                       int32
# course_id                     int32
# course_name                     str
# instructor                      str
# course_duration_hours       float32
# certification_offered         int64
# difficulty_level              int64
# rating                      float32
# enrollment_numbers            int32
# course_price                float32
# feedback_score              float32
# study_material_available      int64
# time_spent_hours            float32
# previous_courses_taken         int8
# dtype: object

# %%
# Set style for plots
sns.set_style("whitegrid")

# Distribution of numerical features
num_cols = ['course_duration_hours', 'course_price', 'feedback_score',
            'time_spent_hours', 'previous_courses_taken', 'rating',
            'enrollment_numbers']

plt.figure(figsize=(15, 10))
for i, col in enumerate(num_cols, 1):
    plt.subplot(3, 3, i)
    sns.histplot(df[col], bins=30, kde=True)
    plt.title(f'Distribution of {col}')
plt.tight_layout()
plt.show()

# %%
# Top courses by enrollment
top_courses = df.groupby('course_name')['enrollment_numbers'].sum().sort_values(ascending=False).head(10)

plt.figure(figsize=(10, 6))
sns.barplot(x=top_courses.values, y=top_courses.index, palette='viridis')
plt.title('Top 10 Courses by Enrollment')
plt.xlabel('Total Enrollment')
plt.ylabel('Course Name')
plt.show()

# %%
# Rating distribution
plt.figure(figsize=(8, 5))
sns.countplot(x='rating', data=df)
plt.title('Distribution of Course Ratings')
plt.show()

# %%
# Correlation matrix
plt.figure(figsize=(10, 8))
corr = df[num_cols].corr()
sns.heatmap(corr, annot=True, cmap='coolwarm', center=0)
plt.title('Correlation Matrix')
plt.show()

# %%
def engineer_features(df):
    """Create new features for recommendation"""
    print("\nPerforming feature engineering...")

    # 1. Create engagement score
    df['engagement_score'] = (df['time_spent_hours'] / df['course_duration_hours']) * df['rating']

    # 2. Create popularity score
    max_enrollment = df['enrollment_numbers'].max()
    df['popularity_score'] = df['enrollment_numbers'] / max_enrollment

    # 3. Create value for money metric
    df['value_for_money'] = df['rating'] / (df['course_price'] + 0.01)

    # 4. Instructor popularity
    instructor_stats = df.groupby('instructor').agg({
        'rating': 'mean',
        'enrollment_numbers': 'sum'
    }).reset_index()
    instructor_stats.columns = ['instructor', 'instructor_avg_rating', 'instructor_total_enrollment']

    df = pd.merge(df, instructor_stats, on='instructor', how='left')

    print("New features created:")
    print("- engagement_score")
    print("- popularity_score")
    print("- value_for_money")
    print("- instructor_avg_rating")
    print("- instructor_total_enrollment")

    return df

df = engineer_features(df)
# Out:
# Performing feature engineering...
# New features created:
# - engagement_score
# - popularity_score
# - value_for_money
# - instructor_avg_rating
# - instructor_total_enrollment

# %%
df
# Out:
#        user_id  course_id                           course_name  \
# 0        15796       9366                  Python for Beginners
# 1          861       1928       Cybersecurity for Professionals
# 2        38159       9541      DevOps and Continuous Deployment
# 3        44733       3708       Project Management Fundamentals
# 4        11285       3361           Ethical Hacking Masterclass
# ...        ...        ...                                   ...
# 99995    10647       5466             Graphic Design with Canva
# 99996    13800       2623   Stock Market and Trading Strategies
# 99997    47131       1556  Networking and System Administration
# 99998    49654       6001             Graphic Design with Canva
# 99999    12929       5763             Graphic Design with Canva
#
#             instructor  course_duration_hours  certification_offered  \
# 0          Emma Harris              39.099998                      1
# 1      Alexander Young              36.299999                      1
# 2       Dr. Mia Walker              13.400000                      1
# 3       Benjamin Lewis              58.299999                      1
# 4         Daniel White              30.799999                      1
# ...                ...                    ...                    ...
# 99995      Emma Harris              17.299999                      1
# 99996   Dr. John Smith              68.400002                      1
# 99997   Dr. John Smith              73.800003                      1
# 99998     Daniel White              30.299999                      1
# 99999     Daniel White              67.000000                      0
#
#        difficulty_level  rating  enrollment_numbers  course_price  \
# 0                     0     5.0               21600    317.500000
# 1                     0     4.3               15379     40.990002
# 2                     0     3.9                6431    380.809998
# 3                     0     3.1               48245    342.799988
# 4                     0     2.8               34556    381.010010
# ...                 ...     ...                 ...           ...
# 99995                 0     3.9               49101    485.339996
# 99996                 0     3.5               35107    162.800003
# 99997                 0     4.3               12146     24.020000
# 99998                 0     3.5                9933    402.239990
# 99999                 0     2.3                3479    135.610001
#
#        feedback_score  study_material_available  time_spent_hours  \
# 0               0.797                         1         17.600000
# 1               0.770                         1         28.969999
# 2               0.772                         1         52.439999
# 3               0.969                         0         22.290001
# 4               0.555                         1         22.010000
# ...               ...                       ...               ...
# 99995           0.838                         1         16.350000
# 99996           0.922                         1         41.939999
# 99997           0.990                         1         15.870000
# 99998           0.630                         1         21.049999
# 99999           0.753                         1          8.630000
#
#        previous_courses_taken  engagement_score  popularity_score  \
# 0                           4          2.250639          0.432009
# 1                           9          3.431708          0.307586
# 2                           4         15.262388          0.128623
# 3                           6          1.185232          0.964919
# 4                           5          2.000909          0.691134
# ...                       ...               ...               ...
# 99995                       3          3.685838          0.982040
# 99996                       7          2.146053          0.702154
# 99997                       5          0.924675          0.242925
# 99998                       4          2.431518          0.198664
# 99999                       1          0.296254          0.069581
#
#        value_for_money  instructor_avg_rating  instructor_total_enrollment
# 0             0.015748               3.948371                    127227072
# 1             0.104878               3.970305                    122930224
# 2             0.010241               3.972397                    124780998
# 3             0.009043               3.967267                    121860396
# 4             0.007349               3.956177                    123623242
# ...                ...                    ...                          ...
# 99995         0.008035               3.948371                    127227072
# 99996         0.021497               3.956280                    125508783
# 99997         0.178943               3.956280                    125508783
# 99998         0.008701               3.956177                    123623242
# 99999         0.016959               3.956177                    123623242
#
# [100000 rows x 19 columns]

# %%
def prepare_model_data(df):
    """Prepare data for recommendation models"""
    print("\nPreparing data for modeling...")

    # For content-based filtering
    course_features = df[['course_id', 'course_duration_hours', 'difficulty_level',
                         'certification_offered', 'study_material_available',
                         'engagement_score', 'popularity_score', 'value_for_money'
                         ]].copy()

    # Drop duplicates (one row per course)
    course_features = course_features.drop_duplicates(subset=['course_id'])

    # Clean data for course features
    course_features = clean_data(course_features.copy())

    # For collaborative filtering
    user_item_matrix = df.pivot_table(index='user_id', columns='course_id', values='rating', fill_value=0)

    # Convert to sparse matrix for memory efficiency
    sparse_user_item = csr_matrix(user_item_matrix.values)

    print(f"Course features shape: {course_features.shape}")
    print(f"User-item matrix shape: {user_item_matrix.shape}")

    return course_features, user_item_matrix, sparse_user_item

course_features, user_item_matrix, sparse_user_item = prepare_model_data(df)
# Out:
# Preparing data for modeling...
#
# Cleaning and preprocessing data...
# Removed 0 duplicate rows
#
# Data types after cleaning:
# course_id                     int32
# course_duration_hours       float32
# difficulty_level            float64
# certification_offered       float64
# study_material_available    float64
# engagement_score            float32
# popularity_score            float64
# value_for_money             float32
# dtype: object
# Course features shape: (9998, 8)
# User-item matrix shape: (43242, 9998)

# %%
def build_content_based_model(course_features):
    """Build content-based recommendation model"""
    print("\nBuilding Content-Based Filtering Model...")

    # Handle potential NaN values by filling with 0
    course_features_filled = course_features.fillna(0)

    # Standardize features
    scaler = StandardScaler()
    course_features_std = course_features_filled.drop('course_id', axis=1)
    course_features_std = pd.DataFrame(scaler.fit_transform(course_features_std),
                                     columns=course_features_std.columns)

    # Compute cosine similarity between courses
    cosine_sim = cosine_similarity(course_features_std)

    # Create course similarity matrix
    course_sim_df = pd.DataFrame(cosine_sim,
                                index=course_features_filled['course_id'],
                                columns=course_features_filled['course_id'])

    print("Content-based model built successfully!")
    return course_sim_df

course_sim_df = build_content_based_model(course_features)
# Out:
# Building Content-Based Filtering Model...
# Content-based model built successfully!

# %%
def build_collaborative_model(df, sample_size=100000):
    """Build collaborative filtering model with a sample"""
    print("\nBuilding Collaborative Filtering Model...")

    # Create a sample of the data for Surprise
    sample_size = min(sample_size, len(df))
    df_sample = df.sample(sample_size, random_state=42)

    # Define the Reader object
    reader = Reader(rating_scale=(df_sample['rating'].min(), df_sample['rating'].max()))

    # Load the dataset
    data = Dataset.load_from_df(df_sample[['user_id', 'course_id', 'rating']], reader)

    # Build the model
    sim_options = {
        'name': 'cosine',
        'user_based': False  # Item-based collaborative filtering
    }

    # Initialize KNNBasic
    knn = KNNBasic(sim_options=sim_options, verbose=False)

    # Evaluate with cross-validation
    print("\nEvaluating Collaborative Filtering Model...")
    start_time = time.time()
    cv_results = cross_validate(knn, data, measures=['RMSE'], cv=3, verbose=True)
    print(f"Evaluation completed in {time.time() - start_time:.2f} seconds")
    print(f"Average RMSE: {np.mean(cv_results['test_rmse']):.4f}")

    return knn, data

knn_model, surprise_data = build_collaborative_model(df)
# Out:
# Building Collaborative Filtering Model...
#
# Evaluating Collaborative Filtering Model...
# Evaluating RMSE of algorithm KNNBasic on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    0.7304  0.7303  0.7305  0.7304  0.0001
# Fit time          2.00    1.84    1.59    1.81    0.17
# Test time         0.37    0.37    0.33    0.36    0.02
# Evaluation completed in 7.61 seconds
# Average RMSE: 0.7304

# %%
def content_based_recommendations(course_id, course_sim_df, df, n=5):
    """Get content-based recommendations for a course"""
    # Get similarity scores for the course
    sim_scores = course_sim_df[course_id]

    # Sort courses by similarity
    sim_scores = sim_scores.sort_values(ascending=False)

    # Get top n most similar courses (excluding itself)
    top_courses = sim_scores.iloc[1:n+1].index

    # Get course details
    recommendations = df[df['course_id'].isin(top_courses)][
        ['course_id', 'course_name', 'instructor', 'difficulty_level', 'rating']
    ].drop_duplicates()

    return recommendations

def get_popular_courses(df, n=5):
    """Get top n popular courses based on enrollment and rating"""
    popular = df.groupby(['course_id', 'course_name', 'instructor']).agg({
        'enrollment_numbers': 'sum',
        'rating': 'mean'
    }).reset_index()

    popular = popular.sort_values(['enrollment_numbers', 'rating'], ascending=False)
    return popular.head(n)[['course_id', 'course_name', 'instructor', 'rating']]

def hybrid_recommendations(user_id, course_sim_df, knn, df, user_item_matrix, n=5):
    """Generate hybrid recommendations"""
    # 1. Get user's previously rated courses
    user_ratings = user_item_matrix.loc[user_id]
    rated_courses = user_ratings[user_ratings > 0].index.tolist()

    # If no ratings, return popular courses
    if not rated_courses:
        return get_popular_courses(df, n)

    # 2. Content-based: Get similar courses to what user has liked
    content_recs = []
    for course in rated_courses:
        if course in course_sim_df.columns:
            similar = content_based_recommendations(course, course_sim_df, df, n)
            content_recs.append(similar)

    if content_recs:
        content_recs = pd.concat(content_recs)
        content_recs = content_recs.sort_values('rating', ascending=False).head(n)

    return content_recs if not content_recs.empty else get_popular_courses(df, n)

print("Recommendation functions defined!")
# Out:
# Recommendation functions defined!

# %%
# Content-based recommendations for a random course
example_course = df['course_id'].sample(1).values[0]
course_name = df[df['course_id'] == example_course]['course_name'].iloc[0]
print(f"\nContent-based recommendations for course: {course_name} (ID: {example_course})")
content_recs = content_based_recommendations(example_course, course_sim_df, df)
content_recs
# Out:
# Content-based recommendations for course: Stock Market and Trading Strategies (ID: 7668)
#        course_id                                course_name  \
# 847         5968                  Advanced Machine Learning
# 1098         403            Data Visualization with Tableau
# 3515        9600       Networking and System Administration
# 4819         403                    AI for Business Leaders
# 5406        9939       Personal Finance and Wealth Building
# 6062        5968                       Python for Beginners
# 8605        5968            Project Management Fundamentals
# 15123       5968                  Graphic Design with Canva
# 15613        403                    AI for Business Leaders
# 16637       2938              Photography and Video Editing
# 18716        403            Cybersecurity for Professionals
# 21351       9939                Game Development with Unity
# 23752       5968                Game Development with Unity
# 24011       9600           DevOps and Continuous Deployment
# 24082       9939                 Cloud Computing Essentials
# 25403        403                Ethical Hacking Masterclass
# 28656        403                  Advanced Machine Learning
# 28855        403                       Python for Beginners
# 29102       2938       Networking and System Administration
# 31252       2938  Blockchain and Decentralized Applications
# 31434       9600             Fitness and Nutrition Coaching
# 35373       2938          Fundamentals of Digital Marketing
# 35680       9600            Data Visualization with Tableau
# 38644       9600       Personal Finance and Wealth Building
# 47168        403                Ethical Hacking Masterclass
# 48030       9600                       Python for Beginners
# 49256       9939                Game Development with Unity
# 49875        403       Personal Finance and Wealth Building
# 50354        403          Mobile App Development with Swift
# 50793        403                    AI for Business Leaders
# 51511        403                    AI for Business Leaders
# 55447        403          Mobile App Development with Swift
# 56420        403              Photography and Video Editing
# 56955        403          Fundamentals of Digital Marketing
# 57736       2938            Cybersecurity for Professionals
# 61167       5968                  Graphic Design with Canva
# 62900       9939          Fundamentals of Digital Marketing
# 63227       9939                       Python for Beginners
# 63472       9600       Networking and System Administration
# 64940       2938                 Cloud Computing Essentials
# 68955       2938       Networking and System Administration
# 70525       5968                    Public Speaking Mastery
# 71539       2938                  Graphic Design with Canva
# 71656       5968              Photography and Video Editing
# 71725       5968             Fitness and Nutrition Coaching
# 73202        403            Project Management Fundamentals
# 75294       5968                  Advanced Machine Learning
# 75310       2938                 Cloud Computing Essentials
# 78334       9600              Photography and Video Editing
# 80357       5968                  Advanced Machine Learning
# 81603       5968            Project Management Fundamentals
# 81636       2938             Fitness and Nutrition Coaching
# 87010       2938                  Graphic Design with Canva
# 93323       2938                Game Development with Unity
# 95524       2938                 Cloud Computing Essentials
# 96448       2938                    Public Speaking Mastery
# 96654       9939            Cybersecurity for Professionals
#
#                 instructor  difficulty_level  rating
# 847           Daniel White                 0     4.5
# 1098      Jessica Martinez                 2     3.5
# 3515             Sarah Lee                 0     3.9
# 4819        Dr. Mia Walker                 1     2.8
# 5406             Sarah Lee                 0     4.1
# 6062        Benjamin Lewis                 0     4.3
# 8605        Charlotte King                 0     3.1
# 15123     Jessica Martinez                 0     3.9
# 15613       Dr. John Smith                 1     3.6
# 16637           Ethan Hall                 0     3.7
# 18716           Liam Adams                 0     4.1
# 21351       Benjamin Lewis                 1     3.9
# 23752       William Thomas                 2     4.8
# 24011       Benjamin Lewis                 0     4.3
# 24082       Benjamin Lewis                 1     5.0
# 25403     Jessica Martinez                 0     3.2
# 28656       Isabella Scott                 0     3.3
# 28855      Sophia Anderson                 0     2.4
# 29102           Liam Adams                 0     3.2
# 31252     Dr. Robert Davis                 0     5.0
# 31434          James Clark                 2     3.0
# 35373       Benjamin Lewis                 1     3.8
# 35680          Emma Harris                 0     5.0
# 38644          Emma Harris                 0     3.8
# 47168     Jessica Martinez                 2     3.0
# 48030     Jessica Martinez                 1     3.2
# 49256       William Thomas                 0     4.6
# 49875       Benjamin Lewis                 1     3.9
# 50354           Liam Adams                 2     4.6
# 50793            Sarah Lee                 0     4.1
# 51511       Dr. John Smith                 0     4.6
# 55447           Liam Adams                 2     4.5
# 56420     Jessica Martinez                 0     3.7
# 56955           Ethan Hall                 0     4.5
# 57736     Dr. Robert Davis                 1     4.4
# 61167       Benjamin Lewis                 0     4.7
# 62900       Dr. John Smith                 1     4.3
# 63227         David Wilson                 1     5.0
# 63472       Isabella Scott                 1     3.7
# 64940       Dr. Mia Walker                 0     3.6
# 68955       Charlotte King                 0     4.2
# 70525     Jessica Martinez                 2     3.8
# 71539       Charlotte King                 0     3.2
# 71656         David Wilson                 2     5.0
# 71725       Benjamin Lewis                 2     4.6
# 73202  Prof. Emily Johnson                 2     2.3
# 75294     Jessica Martinez                 0     3.1
# 75310          James Clark                 1     3.6
# 78334          Emma Harris                 0     4.8
# 80357       Dr. Mia Walker                 1     4.7
# 81603           Liam Adams                 1     4.5
# 81636     Jessica Martinez                 1     4.3
# 87010         David Wilson                 2     3.5
# 93323           Ethan Hall                 2     3.0
# 95524       Dr. Mia Walker                 1     4.1
# 96448     Jessica Martinez                 0     2.7
# 96654       Charlotte King                 0     3.3

# %%
# Hybrid recommendations for a random user
example_user = df['user_id'].sample(1).values[0]
print(f"\nHybrid recommendations for user ID: {example_user}")
hybrid_recs = hybrid_recommendations(example_user, course_sim_df, knn_model, df, user_item_matrix)
hybrid_recs
# Out:
# Hybrid recommendations for user ID: 6942
#        course_id                           course_name      instructor  \
# 10265       7617  Personal Finance and Wealth Building      Liam Adams
# 3579        5731     Fundamentals of Digital Marketing      Ethan Hall
# 29057       5731       Project Management Fundamentals      Ethan Hall
# 51655       7218      DevOps and Continuous Deployment       Sarah Lee
# 72399       4283             Graphic Design with Canva  Dr. Mia Walker
#
#        difficulty_level  rating
# 10265                 0     5.0
# 3579                  1     5.0
# 29057                 2     5.0
# 51655                 2     5.0
# 72399                 0     5.0

# %%
# Show popular courses
print("\nTop 5 Popular Courses Overall:")
get_popular_courses(df)
# Out:
# Top 5 Popular Courses Overall:
#        course_id                          course_name      instructor  \
# 45859       4659  Stock Market and Trading Strategies  Dr. Mia Walker
# 7238         733                 Python for Beginners  Dr. John Smith
# 84317       8541            Advanced Machine Learning  Isabella Scott
# 80300       8129    Fundamentals of Digital Marketing     Emma Harris
# 94391       9562      Cybersecurity for Professionals  William Thomas
#
#          rating
# 45859  3.733334
# 7238   4.766667
# 84317  3.866667
# 80300  3.500000
# 94391  4.050000

# %%
from surprise import SVD, Dataset, Reader
from surprise.model_selection import cross_validate

# Prepare data for Surprise
reader = Reader(rating_scale=(df['rating'].min(), df['rating'].max()))
data = Dataset.load_from_df(df[['user_id', 'course_id', 'rating']], reader)

# Build and evaluate SVD model
print("Training SVD (Matrix Factorization) model...")
start_time = time.time()
svd = SVD()
cv_results = cross_validate(svd, data, measures=['RMSE', 'MAE'], cv=3, verbose=True)
print(f"Training completed in {time.time() - start_time:.2f} seconds")
print(f"Average RMSE: {np.mean(cv_results['test_rmse']):.4f}")
print(f"Average MAE: {np.mean(cv_results['test_mae']):.4f}")

# Train on full dataset
trainset = data.build_full_trainset()
svd.fit(trainset)

def svd_recommendations(user_id, n=5):
    """Generate recommendations using SVD"""
    # Get list of all course IDs
    all_courses = df['course_id'].unique()

    # Get courses user has already taken
    user_courses = df[df['user_id'] == user_id]['course_id'].unique()

    # Predict ratings for courses not taken
    predictions = []
    for course_id in all_courses:
        if course_id not in user_courses:
            pred = svd.predict(user_id, course_id)
            predictions.append((course_id, pred.est))

    # Sort by predicted rating
    predictions.sort(key=lambda x: x[1], reverse=True)

    # Get top n recommendations
    top_courses = [x[0] for x in predictions[:n]]

    # Return course details
    return df[df['course_id'].isin(top_courses)][['course_id', 'course_name', 'instructor', 'rating']].drop_duplicates()

# Test with a sample user
sample_user = df['user_id'].sample(1).values[0]
print(f"\nSVD recommendations for user {sample_user}:")
svd_recommendations(sample_user)
# Out:
# Training SVD (Matrix Factorization) model...
# Evaluating RMSE, MAE of algorithm SVD on 3 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Mean    Std
# RMSE (testset)    0.7463  0.7460  0.7493  0.7472  0.0015
# MAE (testset)     0.6108  0.6125  0.6140  0.6124  0.0013
# Fit time          1.70    1.39    1.17    1.42    0.22
# Test time         0.25    0.25    0.21    0.23    0.02
# Training completed in 6.36 seconds
# Average RMSE: 0.7472
# Average MAE: 0.6124
#
# SVD recommendations for user 2648:
#        course_id                                course_name  \
# 515         5557          Mobile App Development with Swift
# 2393        1590                 Cloud Computing Essentials
# 3004        5557            Project Management Fundamentals
# 4243        5557                       Python for Beginners
# 4541        8888           DevOps and Continuous Deployment
# 4823        7444                Ethical Hacking Masterclass
# 6066        5807            Data Visualization with Tableau
# 9241        7444              Photography and Video Editing
# 11863       5557                    Public Speaking Mastery
# 13765       7444              Photography and Video Editing
# 15786       8888            Data Visualization with Tableau
# 16078       8888       Networking and System Administration
# 16738       5557            Cybersecurity for Professionals
# 18037       5807           DevOps and Continuous Deployment
# 20527       8888            Project Management Fundamentals
# 22070       5807                Ethical Hacking Masterclass
# 23368       5557          Fundamentals of Digital Marketing
# 23528       5557            Data Visualization with Tableau
# 23634       5807            Cybersecurity for Professionals
# 24207       5807                 Cloud Computing Essentials
# 24446       5807                    Public Speaking Mastery
# 27122       7444          Mobile App Development with Swift
# 28193       1590                    AI for Business Leaders
# 29235       1590                 Cloud Computing Essentials
# 29394       8888                    Public Speaking Mastery
# 35520       7444                    Public Speaking Mastery
# 36662       1590                    Public Speaking Mastery
# 40494       8888                 Cloud Computing Essentials
# 42034       7444                 Cloud Computing Essentials
# 47433       7444              Photography and Video Editing
# 55819       8888          Mobile App Development with Swift
# 59162       5807                    AI for Business Leaders
# 64880       1590  Blockchain and Decentralized Applications
# 66460       1590              Photography and Video Editing
# 68238       5557                Ethical Hacking Masterclass
# 68385       5807                  Advanced Machine Learning
# 70611       8888       Personal Finance and Wealth Building
# 74147       7444                    AI for Business Leaders
# 75594       7444                Ethical Hacking Masterclass
# 76214       1590                Ethical Hacking Masterclass
# 76504       5807          Fundamentals of Digital Marketing
# 77388       5807           DevOps and Continuous Deployment
# 80131       5807            Project Management Fundamentals
# 81971       1590          Mobile App Development with Swift
# 89455       7444                    AI for Business Leaders
# 89553       5557                Ethical Hacking Masterclass
# 96108       5557                  Advanced Machine Learning
# 99029       1590          Fundamentals of Digital Marketing
#
#                 instructor  rating
# 515         Benjamin Lewis     4.1
# 2393        Isabella Scott     5.0
# 3004       Alexander Young     4.6
# 4243        Benjamin Lewis     4.2
# 4541       Sophia Anderson     4.7
# 4823          David Wilson     4.7
# 6066         Olivia Taylor     5.0
# 9241           Emma Harris     3.9
# 11863  Prof. Emily Johnson     5.0
# 13765       Dr. Mia Walker     4.5
# 15786  Prof. Emily Johnson     5.0
# 16078         David Wilson     4.4
# 16738            Sarah Lee     4.3
# 18037       Benjamin Lewis     4.6
# 20527         Daniel White     5.0
# 22070           Ethan Hall     4.8
# 23368     Dr. Robert Davis     4.2
# 23528           Ethan Hall     5.0
# 23634          James Clark     3.1
# 24207       Dr. John Smith     4.0
# 24446      Alexander Young     5.0
# 27122       Dr. John Smith     4.3
# 28193           Ethan Hall     4.4
# 29235      Sophia Anderson     4.0
# 29394          James Clark     2.6
# 35520       William Thomas     4.5
# 36662        Olivia Taylor     3.6
# 40494         David Wilson     4.0
# 42034        Michael Brown     5.0
# 47433        Olivia Taylor     4.4
# 55819      Sophia Anderson     4.1
# 59162         David Wilson     5.0
# 64880         David Wilson     4.3
# 66460         Daniel White     4.9
# 68238          James Clark     4.3
# 68385         Daniel White     5.0
# 70611        Olivia Taylor     3.0
# 74147        Olivia Taylor     4.3
# 75594  Prof. Emily Johnson     4.7
# 76214          James Clark     4.6
# 76504      Sophia Anderson     5.0
# 77388       Dr. John Smith     3.6
# 80131            Sarah Lee     3.4
# 81971       Isabella Scott     5.0
# 89455       Dr. Mia Walker     5.0
# 89553       Dr. John Smith     5.0
# 96108       Charlotte King     4.3
# 99029       Dr. Mia Walker     5.0

# %%
from surprise import SVD

print("Working Successfully")
# Out:
# Working Successfully
